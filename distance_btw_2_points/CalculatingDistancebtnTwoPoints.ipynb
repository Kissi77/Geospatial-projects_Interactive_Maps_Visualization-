# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
#
#    ---------------------------------------- 2/2 [geopy]
#
# Successfully installed geographiclib-2.1 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
from geopy.distance import geodesic

data = {
    'City': ['Denver', 'Austin'],
    'Latitude': [39.7392, 30.2672],
    'Longitude': [-104.9903, -97.7431]
}

gdf = gpd.GeoDataFrame(
    data,
    geometry=gpd.points_from_xy(data["Longitude"], data["Latitude"])
)

coords_denver = (gdf.loc[0, "Latitude"], gdf.loc[0, "Longitude"])
coords_austin = (gdf.loc[1, "Latitude"], gdf.loc[1, "Longitude"])

distance = geodesic(coords_denver, coords_austin).kilometers

print(f"Distance between Denver and Austin: {distance:.2f} km")
# Out:
# Distance between Denver and Austin: 1240.67 km

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\emman\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\emman\anaconda3\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\emman\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\emman\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\emman\anaconda3\lib\site-packages (from folium) (2.32.2)
# Requirement already satisfied: xyzservices in c:\users\emman\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\emman\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\emman\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\emman\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\emman\anaconda3\lib\site-packages (from requests->folium) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\emman\anaconda3\lib\site-packages (from requests->folium) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# Midpoint for map centering
midpoint = [
    gdf["Latitude"].mean(),
    gdf["Longitude"].mean()
]

m = folium.Map(location=midpoint, zoom_start=4)

# Add markers for each city
for idx, row in gdf.iterrows():
    folium.Marker(
        location=[row["Latitude"], row["Longitude"]],
        popup=row["City"]
    ).add_to(m)

# Line between Denver and Austin
line = folium.PolyLine(
    locations=[
        (gdf.loc[0, "Latitude"], gdf.loc[0, "Longitude"]),
        (gdf.loc[1, "Latitude"], gdf.loc[1, "Longitude"])
    ],
    color="blue",
    weight=2.5,
    opacity=1
)

m.add_child(line)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cadd6947326a38b267724cf41604623 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cadd6947326a38b267724cf41604623&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cadd6947326a38b267724cf41604623 = L.map(
#                 &quot;map_5cadd6947326a38b267724cf41604623&quot;,
#                 {
#                     center: [35.0032, -101.36670000000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec88947c7d005e617f4dd0725485577d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec88947c7d005e617f4dd0725485577d.addTo(map_5cadd6947326a38b267724cf41604623);
#
#
#             var marker_40900b46c722fc97003a03c48502d614 = L.marker(
#                 [39.7392, -104.9903],
#                 {
# }
#             ).addTo(map_5cadd6947326a38b267724cf41604623);
#
#
#         var popup_20ec01086c0f9528d10af7a53febf831 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4dce3e3fd6ad8d728c2bfe6328d26a7 = $(`&lt;div id=&quot;html_b4dce3e3fd6ad8d728c2bfe6328d26a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denver&lt;/div&gt;`)[0];
#                 popup_20ec01086c0f9528d10af7a53febf831.setContent(html_b4dce3e3fd6ad8d728c2bfe6328d26a7);
#
#
#
#         marker_40900b46c722fc97003a03c48502d614.bindPopup(popup_20ec01086c0f9528d10af7a53febf831)
#         ;
#
#
#
#
#             var marker_05ccee39324b2bc573e718c138f5ab8f = L.marker(
#                 [30.2672, -97.7431],
#                 {
# }
#             ).addTo(map_5cadd6947326a38b267724cf41604623);
#
#
#         var popup_ac74bc661ce1134ed3743f292484eb88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8621b254b5f17b120a0839d4ebe83f4c = $(`&lt;div id=&quot;html_8621b254b5f17b120a0839d4ebe83f4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Austin&lt;/div&gt;`)[0];
#                 popup_ac74bc661ce1134ed3743f292484eb88.setContent(html_8621b254b5f17b120a0839d4ebe83f4c);
#
#
#
#         marker_05ccee39324b2bc573e718c138f5ab8f.bindPopup(popup_ac74bc661ce1134ed3743f292484eb88)
#         ;
#
#
#
#
#             var poly_line_2c9752d2633bfca50ea459c5e4f65c6e = L.polyline(
#                 [[39.7392, -104.9903], [30.2672, -97.7431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_5cadd6947326a38b267724cf41604623);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
